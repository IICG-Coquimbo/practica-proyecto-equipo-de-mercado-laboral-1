# %%
# %load_ext autoreload
# %autoreload 2
from scraper.scraper_benjamin import ejecutar_extraccion
ejecutar_extraccion()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Iniciando extracción forzada para Benjamin-Ramirez...
# Accediendo a: https://www.chiletrabajos.cl/encuentra-un-empleo?p=1
# Progreso actual: 30/500
# Accediendo a: https://www.chiletrabajos.cl/encuentra-un-empleo?p=2
# Progreso actual: 60/500
# Accediendo a: https://www.chiletrabajos.cl/encuentra-un-empleo?p=3
# Progreso actual: 90/500
# Accediendo a: https://www.chiletrabajos.cl/encuentra-un-empleo?p=4
# Progreso actual: 120/500
# Accediendo a: https://www.chiletrabajos.cl/encuentra-un-empleo?p=5
# Progreso actual: 150/500
# Accediendo a: https://www.chiletrabajos.cl/encuentra-un-empleo?p=6
# Progreso actual: 180/500
# Accediendo a: https://www.chiletrabajos.cl/encuentra-un-empleo?p=7
# Progreso actual: 210/500
# Accediendo a: https://www.chiletrabajos.cl/encuentra-un-empleo?p=8
# Progreso actual: 240/500
# Accediendo a: https://www.chiletrabajos.cl/encuentra-un-empleo?p=9
# ...
