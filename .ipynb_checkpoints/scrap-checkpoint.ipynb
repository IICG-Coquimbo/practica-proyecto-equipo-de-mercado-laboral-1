# %%
# Celda 1 — Importar
import pandas as pd
import sys

sys.path.append("/ruta/donde/esta/tu/archivo")  # ajusta si el .py no está en el mismo directorio
from scraper_giannella import extraer_empleos

# %%
# Celda 2 — Ejecutar y obtener datos
registros = extraer_empleos(
    nombre_grupo="Giannella-Rieu",
    meta_registros=500,
    limite_paginas=15
)
# Out:
# Iniciando extracción — Grupo: Giannella Rieu | Meta: 500 registros
#
# ========== Categoría: Informatica ==========
#   Página 1: 15 nuevos | Total: 15
#   Página 2: 15 nuevos | Total: 30
#   Página 3: 16 nuevos | Total: 46
#   Página 4: 16 nuevos | Total: 62
#   Página 5: 16 nuevos | Total: 78
#   Página 6: 12 nuevos | Total: 90
#   Página 7: 15 nuevos | Total: 105
#   Página 8: 16 nuevos | Total: 121
#   Página 9: 13 nuevos | Total: 134
#   Página 10: 16 nuevos | Total: 150
#   Página 11: 9 nuevos | Total: 159
#   Página 12: 13 nuevos | Total: 172
#   Página 13: 11 nuevos | Total: 183
#   Página 14: 14 nuevos | Total: 197
#   Página 15: 9 nuevos | Total: 206
# ========== Categoría: Administracion ==========
#   Página 1: 16 nuevos | Total: 222
#   Página 2: 15 nuevos | Total: 237
#   Página 3: 16 nuevos | Total: 253
#   Página 4: 15 nuevos | Total: 268
#   Página 5: 15 nuevos | Total: 283
#   Página 6: 16 nuevos | Total: 299
#   Página 7: 16 nuevos | Total: 315
# ...

# %%
# Celda 3 — Convertir a DataFrame y visualizar
df = pd.DataFrame(registros)

print(f"Registros obtenidos: {len(df)}")
df.head(10)
# Out:
# Registros obtenidos: 500
#                                      Titulo de Cargo           Empresa   Pais  \
# 0                                                        Cronoshare.cl  Chile
# 1  Informático a domicilio para resolver problema...     Cronoshare.cl  Chile
# 2  Servicio informático a domicilio: PC no recono...     Cronoshare.cl  Chile
# 3        Solicito Personal Para Seguridad o Conserje  GSS SEGURIDAD CL  Chile
# 4                                          SuperUser               SGS  Chile
# 5                  Capataz Muestrera (Valle Copiapo)               SGS  Chile
# 6        Consultor Funcional TI (Perfil JR) - Remoto             ATCOM  Chile
# 7                    Data Analyst Y Engineer Support         BEMAQ SPA  Chile
# 8        Pasantía laboral / Research and Development     Deinsa Global  Chile
# 9          Técnico de Soporte Informático en Tiendas         Falabella  Chile
#
#       Fecha de Captura                                        Descripcion  \
# ...
