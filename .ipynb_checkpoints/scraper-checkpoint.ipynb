# %%
# 1. Importamos TU función desde TU archivo .py
# La ruta es: desde la carpeta 'scraper', el archivo 'scraper_giannella'
from scraper.scraper_giannella import ejecutar_extraccion_final_giannella_rieu

# 2. Ejecutamos tu scraping personal
mis_datos = ejecutar_extraccion_final_giannella_rieu()
