# %%
import pandas as pd
from scraper.scraper_benja import ejecutar_extraccion

print("Iniciando extracción del módulo de Benjamín...")

# 1. Llamar a la función y guardar el resultado
datos_benja = ejecutar_extraccion()

# 2. Mostrar la tabla resultante
if datos_benja:
    df_benja = pd.DataFrame(datos_benja)
    print("\nExtracción finalizada. Vista previa de los datos:")
    
    # 'display' renderiza la tabla nativa de Jupyter Notebook
    display(df_benja)
else:
    print("\nNo se capturaron datos. Revisa la ejecución de la función.")
# Out:
# Iniciando extracción del módulo de Benjamín...
#
# ========== Explorando Categoría: Informatica ==========
#   Timeout en página 1, forzando la siguiente...
#   --- Página 2: 30 nuevos | Total acumulado: 30 ---
#   --- Página 3: 0 nuevos | Total acumulado: 30 ---
#   --- Página 4: 0 nuevos | Total acumulado: 30 ---
#   --- Página 5: 0 nuevos | Total acumulado: 30 ---
#   --- Página 6: 0 nuevos | Total acumulado: 30 ---
#   --- Página 7: 0 nuevos | Total acumulado: 30 ---
#   Demasiadas páginas seguidas de Anuncios Destacados repetidos. Pasando a la siguiente categoría...
#
# ========== Explorando Categoría: Administracion ==========
#   --- Página 1: 26 nuevos | Total acumulado: 56 ---
#   --- Página 2: 23 nuevos | Total acumulado: 79 ---
#   --- Página 3: 0 nuevos | Total acumulado: 79 ---
#   --- Página 4: 0 nuevos | Total acumulado: 79 ---
#   --- Página 5: 0 nuevos | Total acumulado: 79 ---
#   --- Página 6: 0 nuevos | Total acumulado: 79 ---
# ...
