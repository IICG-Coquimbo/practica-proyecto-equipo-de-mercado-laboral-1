# %%
import pandas as pd
from Scrapers.Scraper_Diego import ejecutar_extraccionD

print("Iniciando extracción del módulo de Diego...")

# 1. Llamar a la función y guardar el resultado
datos_diego = ejecutar_extraccionD()

# 2. Mostrar la tabla resultante
if datos_diego:
    df_diego = pd.DataFrame(datos_diego)
    print("\nExtracción finalizada. Vista previa de los datos:")
    
    # 'display' renderiza la tabla nativa de Jupyter Notebook
    display(df_diego)
else:
    print("\nNo se capturaron datos. Revisa la ejecución de la función o los bloqueos del sitio.")
# Out:
# Iniciando extracción del módulo de Diego...
#
# ========== Categoría: Programación ==========
#   --- Página 1 ---
#   Ofertas encontradas: 67
#   No hay más páginas en esta categoría.
#
# ========== Categoría: Diseño ==========
# Error: HTTPConnectionPool(host='localhost', port=46503): Max retries exceeded with url: /session/80bc2ca1459ea4a9cce969c643a2a322/url (Caused by NewConnectionError("HTTPConnection(host='localhost', port=46503): Failed to establish a new connection: [Errno 111] Connection refused"))
#
# Navegador cerrado.
# CONEXIÓN ESTABLECIDA.
#
# RESUMEN:
#   Exitosos : 67
#   Fallidos : 0
#   Total en colección : 1629
#
# Extracción finalizada. Vista previa de los datos:
#                                  titulo_cargo          empresa  \
# 0                      Desarrollador/a Senior  No especificada
# 1                   Desarrollador de Software  No especificada
# 2   Gestor de Proyectos (Product Specialist )  No especificada
# 3                             No especificado  No especificada
# 4                             No especificado  No especificada
# ..                                        ...              ...
# 62                            No especificado  No especificada
# 63                            No especificado  No especificada
# 64                            No especificado  No especificada
# 65                            No especificado  No especificada
# 66                            No especificado  No especificada
#
#                 pais        modalidad       tipo_horario fecha_publicacion  \
# 0   Chile and Mexico           Remoto          Full time            Apr 23
# 1             Hybrid          Híbrido  Junior Internship            abr 21
# 2             Europe           Remoto          Full time            ene 21
# 3    No especificado  No especificada    No especificado   No especificada
# 4    No especificado  No especificada    No especificado   No especificada
# ..               ...              ...                ...               ...
# 62   No especificado  No especificada    No especificado   No especificada
# 63   No especificado  No especificada    No especificado   No especificada
# 64   No especificado  No especificada    No especificado   No especificada
# 65   No especificado  No especificada    No especificado   No especificada
# 66   No especificado  No especificada    No especificado   No especificada
#
#           fecha_captura               descripcion     categoria  \
# 0   2026-05-02 01:55:39  No disponible en listado  Programación
# 1   2026-05-02 01:55:39  No disponible en listado  Programación
# 2   2026-05-02 01:55:39  No disponible en listado  Programación
# 3   2026-05-02 01:55:39  No disponible en listado  Programación
# 4   2026-05-02 01:55:39  No disponible en listado  Programación
# ..                  ...                       ...           ...
# 62  2026-05-02 01:55:41  No disponible en listado  Programación
# 63  2026-05-02 01:55:41  No disponible en listado  Programación
# 64  2026-05-02 01:55:41  No disponible en listado  Programación
# 65  2026-05-02 01:55:41  No disponible en listado  Programación
# 66  2026-05-02 01:55:41  No disponible en listado  Programación
#
#             grupo                       _id
# 0   diegoCastillo  69f5599e09b0e0c40fa345bb
# 1   diegoCastillo  69f5599f09b0e0c40fa345bc
# 2   diegoCastillo  69f5599f09b0e0c40fa345bd
# 3   diegoCastillo  69f5599f09b0e0c40fa345be
# 4   diegoCastillo  69f5599f09b0e0c40fa345bf
# ..            ...                       ...
# 62  diegoCastillo  69f559a409b0e0c40fa345f9
# 63  diegoCastillo  69f559a409b0e0c40fa345fa
# 64  diegoCastillo  69f559a409b0e0c40fa345fb
# 65  diegoCastillo  69f559a409b0e0c40fa345fc
# 66  diegoCastillo  69f559a409b0e0c40fa345fd
#
# [67 rows x 11 columns]

# %%
from Scrapers.Scraper_SofiaUrquieta import ejecutar_scraping_firstjob
datos_sofia = ejecutar_scraping_firstjob()
# Out:
# 🚀 Iniciando recolección para Sofia-Urquieta...
#
# ========== Página 1 ==========
#   Ofertas encontradas: 18
# 📊 Progreso: 18 registros capturados.
