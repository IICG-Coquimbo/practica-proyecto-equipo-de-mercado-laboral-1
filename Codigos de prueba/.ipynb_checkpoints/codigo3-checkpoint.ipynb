# %%
nombre = "Lizette"
edad = 22

proxima_edad = edad + 5

print(f"Hola, {nombre}. En 5 años tendrás {proxima_edad} años.")

lista_numeros = [1, 2, 3, 4, 5]
[x * 2 for x in lista_numeros]
# Out:
# Hola, Lizette. En 5 años tendrás 27 años.
# [2, 4, 6, 8, 10]
