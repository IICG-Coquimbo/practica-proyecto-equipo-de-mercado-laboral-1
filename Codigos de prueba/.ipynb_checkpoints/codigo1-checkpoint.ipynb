# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.python.org/jobs/"
headers = {"User-Agent": "Mozilla/5.0"}

respuesta = requests.get(url, headers=headers)

sopa = BeautifulSoup(respuesta.text, 'html.parser')

resultados = sopa.find_all('a', href=True)

for dato in resultados:
    print(f"Encontrado: {dato.text.strip()}")
# Out:
# Encontrado: Skip to content
# Encontrado: ▼ Close
# Encontrado: Python
# Encontrado: PSF
# Encontrado: Docs
# Encontrado: PyPI
# Encontrado: Jobs
# Encontrado: Community
# Encontrado: ▲ The Python Network
# Encontrado:
# Encontrado: Donate
# Encontrado: ≡ Menu
# Encontrado: A A
# Encontrado: Smaller
# Encontrado: Larger
# Encontrado: Reset
# Encontrado: Socialize
# Encontrado: LinkedIn
# Encontrado: Mastodon
# Encontrado: Chat on IRC
# Encontrado: Twitter
# Encontrado: Jobs
# Encontrado: Types
# Encontrado: Back end
# Encontrado: Big Data
# Encontrado: Cloud
# Encontrado: Database
# Encontrado: Front end
# Encontrado: Image Processing
# Encontrado: Integration
# Encontrado: Lead
# Encontrado: Machine Learning
# Encontrado: Numeric processing
# Encontrado: Operations
# Encontrado: Systems
# Encontrado: Testing
# Encontrado: Text Processing
# Encontrado: Web
# Encontrado: Categories
# Encontrado: Developer / Engineer
# Encontrado: Locations
# Encontrado: Telecommute
# Encontrado: Atlanta – US
# Encontrado: Bengaluru, Karnataka – India
# Encontrado: Cambridge, Massachusetts – United States
# Encontrado: Canton, OH – USA
# Encontrado: Fully remote, East Coast Preferred – United States
# Encontrado: Garland, TX – United States
# Encontrado: Hamburg – Germany
# Encontrado: London – United Kingdom
# Encontrado: Mountain View, California – United States
# Encontrado: Remote (EU), Overijsel – Remote (EU)
# Encontrado: Remote – Remote
# Encontrado: Remote – United States
# Encontrado: Remote – USA
# Encontrado: Remote – USA
# Encontrado: Remote – (USA only)
# Encontrado: San Francisco, CA – USA
# Encontrado: Submit
# Encontrado: Senior Python Developer - full stack
# Encontrado: Remote (EU), Overijsel, Remote (EU)
# Encontrado: Back end
# Encontrado: Big Data
# Encontrado: Cloud
# Encontrado: Database
# Encontrado: Machine Learning
# Encontrado: Numeric processing
# Encontrado: Operations
# Encontrado: Systems
# Encontrado: Testing
# Encontrado: Developer / Engineer
# Encontrado: Senior Research Software Engineer (Multiphoton Microscopy)
# Encontrado: London, United Kingdom
# Encontrado: Big Data
# Encontrado: Image Processing
# Encontrado: Developer / Engineer
# Encontrado: Senior Research Software Engineer (Neural and Behavioural Data)
# Encontrado: London, United Kingdom
# Encontrado: Big Data
# Encontrado: Database
# Encontrado: Image Processing
# Encontrado: Numeric processing
# Encontrado: Developer / Engineer
# Encontrado: Python Software Engineer
# Encontrado: Remote, Remote, USA
# Encontrado: Back end
# Encontrado: Integration
# Encontrado: Systems
# Encontrado: Testing
# Encontrado: Web
# Encontrado: Developer / Engineer
# Encontrado: Python Developer - Remote
# Encontrado: Atlanta, US
# Encontrado: Cloud
# Encontrado: Web
# Encontrado: Developer / Engineer
# Encontrado: Senior Python Developer
# Encontrado: Remote, USA
# Encontrado: Back end
# Encontrado: Text Processing
# Encontrado: Developer / Engineer
# Encontrado: Senior Python Developer/DevOps Engineer
# Encontrado: Remote, (USA only)
# Encontrado: Back end
# Encontrado: Cloud
# Encontrado: Developer / Engineer
# Encontrado: Python Tech Lead
# Encontrado: Remote, Remote
# Encontrado: Back end
# Encontrado: Developer / Engineer
# Encontrado: Infrastructure Engineer
# Encontrado: Remote, USA
# Encontrado: Back end
# Encontrado: Cloud
# Encontrado: Database
# Encontrado: Front end
# Encontrado: Operations
# Encontrado: Systems
# Encontrado: Web
# Encontrado: Developer / Engineer
# Encontrado: Senior Python Engineer (backend focused)
# Encontrado: Garland, TX, United States
# Encontrado: Back end
# Encontrado: Database
# Encontrado: Front end
# Encontrado: Operations
# Encontrado: Systems
# Encontrado: Developer / Engineer
# Encontrado: DevOps Engineer-FULLY REMOTE-US, CANADA, EUROPE only
# Encontrado: Mountain View, California, United States
# Encontrado: Cloud
# Encontrado: Developer / Engineer
# Encontrado: Senior Back-End Python Engineer - FULLY REMOTE-WORLDWIDE
# Encontrado: Mountain View, California, United States
# Encontrado: Back end
# Encontrado: Developer / Engineer
# Encontrado: Senior Full-Stack Engineer (remote)
# Encontrado: Hamburg, Germany
# Encontrado: Back end
# Encontrado: Front end
# Encontrado: Lead
# Encontrado: Machine Learning
# Encontrado: Developer / Engineer
# Encontrado: Junior Software Engineer
# Encontrado: San Francisco, CA, USA
# Encontrado: Back end
# Encontrado: Front end
# Encontrado: Developer / Engineer
# Encontrado: Junior Full Stack Developer
# Encontrado: Remote, Remote, United States
# Encontrado: Back end
# Encontrado: Front end
# Encontrado: Developer / Engineer
# Encontrado: Senior Python Backend Developer
# Encontrado: Canton, OH, USA
# Encontrado: Back end
# Encontrado: Developer / Engineer
# Encontrado: Senior Software Engineer
# Encontrado: Fully remote, East Coast Preferred, United States
# Encontrado: Back end
# Encontrado: Cloud
# Encontrado: Front end
# Encontrado: Machine Learning
# Encontrado: Web
# Encontrado: Developer / Engineer
# Encontrado: Senior Data Privacy Software Developer
# Encontrado: Cambridge, Massachusetts, United States
# Encontrado: Machine Learning
# Encontrado: Numeric processing
# Encontrado: Developer / Engineer
# Encontrado: Senior Backend Python Developer
# Encontrado: Bengaluru, Karnataka, India
# Encontrado: Back end
# Encontrado: Developer / Engineer
# Encontrado: job submission how-to
# Encontrado: how-to document
# Encontrado: login
#     and use this form
# Encontrado: logging in now
# Encontrado: PSF Python Job Board team
# Encontrado: Subscribe via RSS
# Encontrado: Follow The PSF via Twitter
# Encontrado: ▲ Back to Top
# Encontrado: About
# Encontrado: Applications
# Encontrado: Quotes
# Encontrado: Getting Started
# Encontrado: Help
# Encontrado: Python Brochure
# Encontrado: Downloads
# Encontrado: All releases
# Encontrado: Source code
# Encontrado: Windows
# Encontrado: macOS
# Encontrado: Android
# Encontrado: Other Platforms
# Encontrado: License
# Encontrado: Alternative Implementations
# Encontrado: Documentation
# Encontrado: Docs
# Encontrado: Audio/Visual Talks
# Encontrado: Beginner's Guide
# Encontrado: FAQ
# Encontrado: Non-English Docs
# Encontrado: PEP Index
# Encontrado: Python Books
# Encontrado: Python Essays
# Encontrado: Community
# Encontrado: Diversity
# Encontrado: Mailing Lists
# Encontrado: IRC
# Encontrado: Forums
# Encontrado: PSF Annual Impact Report
# Encontrado: Python Conferences
# Encontrado: Special Interest Groups
# Encontrado: Python Logo
# Encontrado: Python Wiki
# Encontrado: Code of Conduct
# Encontrado: Community Awards
# Encontrado: Get Involved
# Encontrado: Shared Stories
# Encontrado: Success Stories
# Encontrado: Arts
# Encontrado: Business
# Encontrado: Education
# Encontrado: Engineering
# Encontrado: Government
# Encontrado: Scientific
# Encontrado: Software Development
# Encontrado: News
# Encontrado: Python News
# Encontrado: PSF Newsletter
# Encontrado: PSF News
# Encontrado: PyCon US News
# Encontrado: News from the Community
# Encontrado: Events
# Encontrado: Python Events
# Encontrado: User Group Events
# Encontrado: Python Events Archive
# Encontrado: User Group Events Archive
# Encontrado: Submit an Event
# Encontrado: Contributing
# Encontrado: Developer's Guide
# Encontrado: Issue Tracker
# Encontrado: python-dev list
# Encontrado: Core Mentorship
# Encontrado: Report a Security Issue
# Encontrado: ▲ Back to Top
# Encontrado: Help & General Contact
# Encontrado: Diversity Initiatives
# Encontrado: Submit Website Bug
# Encontrado: Status
# Encontrado: Python Software Foundation
# Encontrado: Legal Statements
# Encontrado: Privacy Notice
