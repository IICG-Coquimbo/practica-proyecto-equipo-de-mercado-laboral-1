# %%
from scraper.scraper_lizette import ejecutar_extraccion_final_lizette
ejecutar_extraccion_final_lizette()
# Out:
# Iniciando extracción: Lizette-Sanmartin (Camuflaje activado)...
# Bloqueo detectado (Código 403). Reintentando con pausa...
