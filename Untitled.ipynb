# %%
from scraper.scraper_lizette import ejecutar_extraccion_final_lizette
ejecutar_extraccion_final_lizette()
# Out:
# Iniciando extracción SEGURA: Lizette-Sanmartin en LinkedIn...
# Progreso: 9/500
# Progreso: 16/500
# Progreso: 25/500
# Progreso: 34/500
# Progreso: 44/500
# Progreso: 54/500
# Progreso: 64/500
# Progreso: 74/500
# Progreso: 84/500
# Progreso: 94/500
# Progreso: 104/500
# Progreso: 114/500
# Progreso: 124/500
# Progreso: 134/500
# Progreso: 142/500
# Progreso: 152/500
# Progreso: 162/500
# Progreso: 169/500
# Progreso: 177/500
# Progreso: 186/500
# Progreso: 195/500
# Progreso: 204/500
# Progreso: 213/500
# Progreso: 223/500
# Progreso: 231/500
# Progreso: 241/500
# Progreso: 250/500
# Progreso: 260/500
# Progreso: 270/500
# Progreso: 280/500
# Progreso: 290/500
# Progreso: 300/500
# Progreso: 306/500
# Progreso: 315/500
# Progreso: 325/500
# Progreso: 335/500
# Progreso: 340/500
# Progreso: 350/500
# Progreso: 360/500
# Progreso: 370/500
# Status 400. Intentando saltar...
# --- ¡ÉXITO! Se cargaron 370 registros ---
# [{'Titulo del cargo': 'Staff Cine - 20 horas a la semana - Cinepolis Parque Arauco - Las Condes',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cine Hoyts',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3edd')},
#  {'Titulo del cargo': 'RECEPCIONISTA',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cine Hoyts',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ede')},
#  {'Titulo del cargo': 'Staff 44 hrs. Cinépolis Estación Central',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cine Hoyts',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Padre Hurtado, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3edf')},
#  {'Titulo del cargo': 'Staff Cine - 44 horas a la semana - Cinepolis Parque Arauco',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cine Hoyts',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Las Condes, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ee0')},
#  {'Titulo del cargo': 'Staff 44 Horas Cinépolis  La Reina',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cine Hoyts',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'La Reina, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ee1')},
#  {'Titulo del cargo': 'Banco de Talentos: Representantes de Servicio al Cliente',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ecolab',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ee2')},
#  {'Titulo del cargo': 'Auxiliar de Aseo - 45 horas - Cinépolis Plaza Egaña',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cine Hoyts',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'La Reina, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ee3')},
#  {'Titulo del cargo': 'Atención al cliente - 20 Horas - Cinépolis Quillota',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cine Hoyts',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Quillota, Valparaiso Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ee4')},
#  {'Titulo del cargo': 'Auxiliar de Recursos Humanos 44 Hrs - copia',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cine Hoyts',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'San Bernardo, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ee5')},
#  {'Titulo del cargo': 'Auxiliar de Farmacia - Peñalolén',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'ATCOM Chile',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Peñalolén, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ee6')},
#  {'Titulo del cargo': 'Supervisor Senior - 44 horas semanales - Parque Arauco Las Condes',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cine Hoyts',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Las Condes, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ee7')},
#  {'Titulo del cargo': 'Asistente de Andén FULL TIME y PART TIME',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Flix',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ee8')},
#  {'Titulo del cargo': 'Asistente de Bodega - Independencia',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': "Fashion's Park S.A.",
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ee9')},
#  {'Titulo del cargo': 'Team Player Omnicomerciante PEAK DE INVIERNO 20 y 30 horas- Decathlon Costanera',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Decathlon',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Providencia, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3eea')},
#  {'Titulo del cargo': 'Team Player Omnicomerciante 20hrs - Decathlon Costanera',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Decathlon',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Providencia, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3eeb')},
#  {'Titulo del cargo': 'Bodeguero',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Minera',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3eec')},
#  {'Titulo del cargo': 'Puestos vacantes: Operadora(or) Despacho (20066)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Grupo Antofagasta Minerals',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3eed')},
#  {'Titulo del cargo': 'Atención al cliente (Crew) Zona Oriente',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'HPDM Entretención',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3eee')},
#  {'Titulo del cargo': 'Secretaria Recepcionista Automotriz',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Bruno Fritsch',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3eef')},
#  {'Titulo del cargo': 'Ejecutivo Preferente',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Isapre Vida Tres',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ef0')},
#  {'Titulo del cargo': 'Analista Gestión de Personas (Plazo Fijo)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Scotiabank',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Las Condes, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ef1')},
#  {'Titulo del cargo': 'Consultoría Administrativa y de Apoyo a Eventos',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Inter-American Development Bank',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ef2')},
#  {'Titulo del cargo': 'OPERADOR B (Faena Chuquicamata-sin campamento)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Empresa Líder',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ef3')},
#  {'Titulo del cargo': '(080) Gestor(a) de Casos - SA Región Metropolitana',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Corporación Opción',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ef4')},
#  {'Titulo del cargo': 'Asistente de Atención al Cliente Junior',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'PSINet',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Temuco, Araucanía Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ef5')},
#  {'Titulo del cargo': 'ENCARGADA MISHKA - Chile, Casa Costanera',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'MISHKA',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Las Condes, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ef6')},
#  {'Titulo del cargo': 'Asistente de Recursos Humanos',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'REST911',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ef7')},
#  {'Titulo del cargo': 'Asistente comercial',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Know How S.A',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ef8')},
#  {'Titulo del cargo': 'Anfitrión de servicio al cliente aeropuerto',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cabify',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3ef9')},
#  {'Titulo del cargo': 'VENDEDOR PART TIME - Mall Barrio Independencia',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Lapiz Lopez',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3efa')},
#  {'Titulo del cargo': 'Bodeguero',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'eCook',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3efb')},
#  {'Titulo del cargo': '(302) Apoyo Administrativo y Contable - LAS Maule',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Corporación Opción',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Talca, Maule Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3efc')},
#  {'Titulo del cargo': 'Asistente de Reclutamiento y Selección',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Global Talent',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3efd')},
#  {'Titulo del cargo': 'ID 0436 SERPAJ VIÑA BUSCA DIRECTOR/A PARA PROGRAMA DE INFANCIA',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Serpaj Chile',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Coquimbo, Coquimbo Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3efe')},
#  {'Titulo del cargo': 'Operador(a) de Combustible y/o Lubricantes, 7x7 Sierra Gorda',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'CSI LTDA.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3eff')},
#  {'Titulo del cargo': 'Trabajador/a Social para residencia de niñas ubicada en la Pintana',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Corporación Crecer Mejor',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f00')},
#  {'Titulo del cargo': 'Manipulador/a de alimentos (40 hrs) Residencia Juvenil',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Fundación Educere',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f01')},
#  {'Titulo del cargo': 'Recepcionista Deportivo',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Estadio Español de Las Condes',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f02')},
#  {'Titulo del cargo': 'Bodeguero Apoyo',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Touch Latam Chile',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f03')},
#  {'Titulo del cargo': 'Asistente SAC Full Time - Cenco Costanera',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cencosud S.A.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago Metropolitan Area',
#   '_id': ObjectId('69eedd804695941a582e3f04')},
#  {'Titulo del cargo': 'Recepcionista/Administrativo - Portillo - Chicureo',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Americar',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f05')},
#  {'Titulo del cargo': 'Operador de Monitoreo y Briefing (Turnos Rotativos 6x1)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Selección GTP',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f06')},
#  {'Titulo del cargo': 'Jefe/a de Tienda - Mall Plaza Egaña',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Natura',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago Metropolitan Area',
#   '_id': ObjectId('69eedd804695941a582e3f07')},
#  {'Titulo del cargo': 'Secretaria/o Administrativo - Las Condes',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Grupo Cetep',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f08')},
#  {'Titulo del cargo': 'Team Player Omnicomerciante 20 hrs Peak Invierno Vespucio',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Decathlon',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'La Florida, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f09')},
#  {'Titulo del cargo': '(100) Auxiliar de Aseo - RM Programas del Servicio de Renserción Social Juvenil',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Corporación Opción',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f0a')},
#  {'Titulo del cargo': 'OPERADOR PLANTA CONCENTRADORA - FAENA ANTOFAGASTA',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Minera Group',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Antofagasta, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f0b')},
#  {'Titulo del cargo': 'Recepcionista Hotelero',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Hotel Termas de Puyehue',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Osorno, Los Lagos Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f0c')},
#  {'Titulo del cargo': 'Ayudantes de Producción',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'San Camilo, Panadería y Pastelería',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f0d')},
#  {'Titulo del cargo': 'Sumate al movimiento por el planeta, siendo ejecutivo de donativos por Call Cent',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'CGS | CGS DIGITAL',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f0e')},
#  {'Titulo del cargo': 'Asistente de Servicios Generales, Dirección de Administración y Finanzas, Sede Concepción',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Universidad Tecnica Federico Santa Maria',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Concepcion, Biobío Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f0f')},
#  {'Titulo del cargo': 'Auxiliar de Botiquín (Diurno)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Teletón',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f10')},
#  {'Titulo del cargo': 'Ejecutivo Clientes Pyme - Nueva Las Condes',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Itaú Chile',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Las Condes, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f11')},
#  {'Titulo del cargo': 'Asistente Geólogo Geotecnia Calama',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Geoblast',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f12')},
#  {'Titulo del cargo': 'Jefe(a) de Turno - Mantos Blancos (7x7), Antofagasta',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'CSI LTDA.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Antofagasta, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f13')},
#  {'Titulo del cargo': 'REQ8385 - EJECUTIVO ATENCION CLIENTES',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Salfa Rent',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f14')},
#  {'Titulo del cargo': 'Ejecutivo Comercial (Vehículos Usados) - Rancagua',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Salfa Rent',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Rancagua Metropolitan Area',
#   '_id': ObjectId('69eedd804695941a582e3f15')},
#  {'Titulo del cargo': 'Supervisor de Operaciones',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cine Hoyts',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f16')},
#  {'Titulo del cargo': 'Guardias con o sin curso Vigente Tienda Adidas $600.000/ Mall Costanera Center 4x4 dia',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'ISEG CHILE',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f17')},
#  {'Titulo del cargo': 'Supervisor Senior - Encargado de Conjunto - Temuco',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cine Hoyts',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Temuco, Araucanía Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f18')},
#  {'Titulo del cargo': 'ATENCION CLIENTE PANADERIA',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Baco Vino y Bistro',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f19')},
#  {'Titulo del cargo': 'Secretaria recepcionista de Clinica',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'DELPRO INGENIERÍA',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Concón, Valparaiso Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f1a')},
#  {'Titulo del cargo': 'Recepcionista para Centro de Estética - Las Condes',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Tafuku Consultores',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Las Condes, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f1b')},
#  {'Titulo del cargo': 'Administrativo de Recursos Humanos Part Time / Inclusión',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'RECLUTAMIENTO',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'La Cisterna, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f1c')},
#  {'Titulo del cargo': 'TRABAJADOR/A SOCIAL Residencia Juvenil',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Fundación Educere',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f1d')},
#  {'Titulo del cargo': 'Asistente de Comunicaciones',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Veltis Latam',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f1e')},
#  {'Titulo del cargo': 'Vendedor Part Time Mall Barrio Independencia, CHL',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Skechers',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Independencia, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f1f')},
#  {'Titulo del cargo': 'Asesor/a de clientes // Part Time 20 HRS // Americanino Mall Plaza Norte',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Falabella',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Huechuraba, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f20')},
#  {'Titulo del cargo': 'Ejecutivo/a Back Office - Santiago',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Scotiabank',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f21')},
#  {'Titulo del cargo': 'Administrativo/a - Americar (Hibrido)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Automotriz Coseche',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Huechuraba, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f22')},
#  {'Titulo del cargo': 'Ayudante de Bodega Santiago',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Milan Fabjanovic y Cia. Ltda.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f23')},
#  {'Titulo del cargo': 'Ejecutivo/a de Cuentas Preferente - Sucursal Vicuña Mackenna',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Scotiabank',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f24')},
#  {'Titulo del cargo': 'Ejecutiva Consulta',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Clínica Oftalmológica Pasteur',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f25')},
#  {'Titulo del cargo': 'Cajero - Administrativo  Placilla',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'San Dámaso',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Valparaíso, Valparaiso Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f26')},
#  {'Titulo del cargo': 'Puestos vacantes: Operadora(o) Producción (19992)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Grupo Antofagasta Minerals',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f27')},
#  {'Titulo del cargo': 'Asistente de Reclutamiento y Selección',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'MindFit Academia',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f28')},
#  {'Titulo del cargo': 'Ejecutivos(as) Atención al Cliente - Temuco',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'PSINet',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Temuco, Araucanía Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f29')},
#  {'Titulo del cargo': 'Encargado(a) de Relaciones Laborales – Codelco EP40',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'J.E.J. INGENIERÍA S.A.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Antofagasta, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f2a')},
#  {'Titulo del cargo': 'Administrativo RRHH',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Grupo VL',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f2b')},
#  {'Titulo del cargo': 'Asistente Administrativo. Para Finanzas y Recursos Humanos.',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ingeleco Ltda',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f2c')},
#  {'Titulo del cargo': 'Staff - Cinépolis Espacio Urbano Melipilla',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cine Hoyts',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Melipilla, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f2d')},
#  {'Titulo del cargo': 'Operador',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'LATAM Airlines',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f2e')},
#  {'Titulo del cargo': 'Empleado de tienda',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Action',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'La Florida, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f2f')},
#  {'Titulo del cargo': 'Agente de Atención al Cliente | Customer Experience',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cencosud S.A.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago Metropolitan Area',
#   '_id': ObjectId('69eedd804695941a582e3f30')},
#  {'Titulo del cargo': 'AUXILIAR DE SERVICIOS HOSPITAL ROBERTO DEL RIO',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'The eMail Company',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f31')},
#  {'Titulo del cargo': 'COLEGIO NECESITA ENCARGADO CONVIVENCIA ESCOLAR',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Corporación Educacional Aprender',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f32')},
#  {'Titulo del cargo': 'Asistente de Contratación y Remuneraciones',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Myra Salud',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f33')},
#  {'Titulo del cargo': 'Encargado(a) de Tienda -Tiendas Región Metropolitana',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'All Nutrition',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Puente Alto, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f34')},
#  {'Titulo del cargo': 'Operario de Bodega Multifuncional',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'M3GA SOLUCIONES',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f35')},
#  {'Titulo del cargo': 'Recepcionista',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Lo Valledor AASA',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f36')},
#  {'Titulo del cargo': 'Captador para Campaña Navideña para marca Deportiva',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Touch Latam Chile',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f37')},
#  {'Titulo del cargo': 'Visitador(a) de Obras – Región Metropolitana',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'DFV Ingeniería y Gestión',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f38')},
#  {'Titulo del cargo': 'Operario Atención a Clientes Family Park',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'HPDM Entretención',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f39')},
#  {'Titulo del cargo': 'Jefe(a) del Servicio de Alimentación, Dirección de Administración y Finanzas, Sede Viña del Mar',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Universidad Tecnica Federico Santa Maria',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Valparaíso, Valparaiso Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f3a')},
#  {'Titulo del cargo': 'ASISTENTE DE BODEGA BODEGA E INVENTARIO',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Empresa Industrial',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f3b')},
#  {'Titulo del cargo': 'Staff (Cinepolito)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cine Hoyts',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f3c')},
#  {'Titulo del cargo': 'Operador de Comida Rápida Part Time Fines de Semana y Festivos Mall Plaza Oeste',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'FANTASILANDIA',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f3d')},
#  {'Titulo del cargo': 'Celador Captaciones Interior Calama 7X7',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Aguas Antofagasta',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Antofagasta, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f3e')},
#  {'Titulo del cargo': 'CONSERJE CON OS10',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ilustre Municipalidad de Villa Alemana',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Villa Alemana, Valparaiso Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f3f')},
#  {'Titulo del cargo': 'Ejecutivos/as Servicio al Cliente y RRSS 30/44 hrs. en Call Center',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'CGS | CGS DIGITAL',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f40')},
#  {'Titulo del cargo': 'AYUDANTE DE BODEGA-FITTING Y MATRICERÍA',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ilustre Municipalidad de Villa Alemana',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Villa Alemana, Valparaiso Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f41')},
#  {'Titulo del cargo': 'Asesora/ Asesor Comercial de Servicios Funerarios',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Funerarias Ultima Morada',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f42')},
#  {'Titulo del cargo': 'Auxiliar de Bodega II - Warehouse Worker II',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'UPS',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f43')},
#  {'Titulo del cargo': 'Team Player Omnicomerciante 30hrs - Decathlon Costanera',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Decathlon',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Providencia, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f44')},
#  {'Titulo del cargo': 'Puestos vacantes: Especialista de Categoría (20159)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Grupo Antofagasta Minerals',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f45')},
#  {'Titulo del cargo': 'Asistente de Bodega - Estación Central',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': "Fashion's Park S.A.",
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e3f46')},
#  {'Titulo del cargo': 'Asistente administrativa Part-time',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Centro Medico & Dental San Diego',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
# ...
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Banco de Chile',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e402a')},
#  {'Titulo del cargo': 'Cocineros',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Bar Liguria Ltda.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e402b')},
#  {'Titulo del cargo': 'Analista Inteligencia de Negocios',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'BancoEstado',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago Metropolitan Area',
#   '_id': ObjectId('69eedd804695941a582e402c')},
#  {'Titulo del cargo': 'Torre de Control (junior) - Coseche, La Florida',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'COSECHE',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e402d')},
#  {'Titulo del cargo': 'Cajero (a) – Santiago, Región Metropolitana, Chile',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Western Union',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e402e')},
#  {'Titulo del cargo': 'Analista de Remuneraciones',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'MOVIRENTCOL',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e402f')},
#  {'Titulo del cargo': 'Ejecutivo de Servicio al Cliente y Post Venta',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cognitas S.A',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4030')},
#  {'Titulo del cargo': 'Analista de Procesos - Gerencia Operaciones Vida',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Consorcio',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4031')},
#  {'Titulo del cargo': 'Asistente de Transporte',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'AGROCOMMERCE',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4032')},
#  {'Titulo del cargo': 'Asesor/a Bienestar Vitaminas y Suplementos Multifunción - San Miguel',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Salcobrand',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4033')},
#  {'Titulo del cargo': 'Vendedor/a Part Time (20 hrs)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'IXComercio',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4034')},
#  {'Titulo del cargo': 'Secretaria de Gerencia',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Wall Partners',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4035')},
#  {'Titulo del cargo': 'Supervisor para Faena',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'FREEMAQ SPA',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4036')},
#  {'Titulo del cargo': 'Cuidador/a Terapéutico/a (día) Residencia Juvenil',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Fundación Educere',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4037')},
#  {'Titulo del cargo': 'Operarios/as de Producción',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ecolab',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4038')},
#  {'Titulo del cargo': 'Jefe/a de Operaciones',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Buses Altas Cumbres',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4039')},
#  {'Titulo del cargo': 'Asistente Logistico',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Grupo Maclean Servicios Integrales',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Padre Hurtado, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e403a')},
#  {'Titulo del cargo': 'Psicólogo/a – Reclutamiento y Selección',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Emetel Limitada',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e403b')},
#  {'Titulo del cargo': 'Administrativo de Adquisiciones',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'AMESTI',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e403c')},
#  {'Titulo del cargo': 'Reclutador/a',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Techint Engineering & Construction',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e403d')},
#  {'Titulo del cargo': 'Bodeguero automotriz - La Cisterna, Salazar Israel',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Salazar Israel',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e403e')},
#  {'Titulo del cargo': 'Operario de Bodega',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Mintral',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Antofagasta, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e403f')},
#  {'Titulo del cargo': 'Operadores/as de Tráfico de buses: Estación Central',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Selección GTP',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4040')},
#  {'Titulo del cargo': 'Administrador(a) de Academia de Baristas – Mumac Academy',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Europa Secreta',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4041')},
#  {'Titulo del cargo': 'Analista Comercial de Adquisición de Grandes Cuentas - Fintech',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Mercado Libre',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago Metropolitan Area',
#   '_id': ObjectId('69eedd804695941a582e4042')},
#  {'Titulo del cargo': 'Administrativo Logistica',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Grupo Maclean Servicios Integrales',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4043')},
#  {'Titulo del cargo': 'Supervisor(a) de Calidad, Servicio de Alimentación, Campus Santiago San Joaquín y Vitacura',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Universidad Tecnica Federico Santa Maria',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4044')},
#  {'Titulo del cargo': 'Analista de Personas con conocimiento en DO y Reclutamiento',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Unibag',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Colina, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4045')},
#  {'Titulo del cargo': 'Analista de Logística',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Global Talent',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4046')},
#  {'Titulo del cargo': 'Líder de Experiencia de Clientes - Gerencia Marketing y Clientes',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Consorcio',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4047')},
#  {'Titulo del cargo': 'Encargado de Línea DyP - Salazar Israel, Huechuraba',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Salazar Israel',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4048')},
#  {'Titulo del cargo': 'Analista Químico',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Grupo Maclean Servicios Integrales',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e4049')},
#  {'Titulo del cargo': 'Administrador de Contrato/Calama',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Almar Water Servicios Latam',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e404a')},
#  {'Titulo del cargo': 'Operador/a Procesos - Lomas Bayas',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Glencore',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Sierra Gorda, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e404b')},
#  {'Titulo del cargo': '¡URGENTE! Operario Logístico',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Deliboo',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago, Santiago Metropolitan Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e404c')},
#  {'Titulo del cargo': 'Bodeguero – Calama',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Almar Water Servicios Latam',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e404d')},
#  {'Titulo del cargo': 'Subadministrador de Operaciones (Transporte de pasajeros)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '27/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'General',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Viggo',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta Region, Chile',
#   '_id': ObjectId('69eedd804695941a582e404e')}]
