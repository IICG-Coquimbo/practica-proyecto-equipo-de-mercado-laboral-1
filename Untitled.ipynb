# %%
from scraper.scraper_lizette import ejecutar_extraccion_final_lizette
ejecutar_extraccion_final_lizette()
# Out:
# Iniciando extracción SEGURA: Lizette-Sanmartin...
# Progreso: 19/500
# Progreso: 36/500
# Progreso: 52/500
# Progreso: 70/500
# Progreso: 90/500
# Progreso: 105/500
# Progreso: 118/500
# Progreso: 137/500
# Progreso: 147/500
# Progreso: 163/500
# Progreso: 183/500
# Progreso: 203/500
# Progreso: 223/500
# Progreso: 237/500
# Progreso: 253/500
# Progreso: 268/500
# Progreso: 287/500
# Progreso: 307/500
# Progreso: 326/500
# Progreso: 344/500
# Progreso: 361/500
# Progreso: 380/500
# Progreso: 400/500
# Progreso: 419/500
# Progreso: 437/500
# Progreso: 457/500
# Progreso: 476/500
# Progreso: 495/500
# Progreso: 500/500
# ¡LOGRADO! 500 registros en tu Atlas.
# [{'Titulo del cargo': 'químico farmacéutico',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'químico farmacéutico',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Puerto Montt, Los Lagos',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d7d')},
#  {'Titulo del cargo': 'Ejecutivo Comercial B2B para OTEC',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ejecutivo Comercial B2B para OTEC',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Las condes, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d7e')},
#  {'Titulo del cargo': 'Técnico Mecánico',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Técnico Mecánico',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - La Granja, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d7f')},
#  {'Titulo del cargo': 'encargado/a de opraciones',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'encargado/a de opraciones',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Providencia, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d80')},
#  {'Titulo del cargo': 'recepcionista vendedor',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'recepcionista vendedor',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Ñuñoa, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d81')},
#  {'Titulo del cargo': 'Dibujante Técnico AutoCAD',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Dibujante Técnico AutoCAD',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Providencia, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d82')},
#  {'Titulo del cargo': 'Asistente de facturación y cobranza',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Asistente de facturación y cobranza',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago Centro, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d83')},
#  {'Titulo del cargo': 'Jornal',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Jornal',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - La Florida, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d84')},
#  {'Titulo del cargo': 'Subgerente(a) HSEQ',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Subgerente(a) HSEQ',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,4',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d85')},
#  {'Titulo del cargo': 'Reponedor Nocturno para Supermercado  en Salvador Allende , Illapel',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Reponedor Nocturno para Supermercado  en Salvador Allende , Illapel',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,7',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d86')},
#  {'Titulo del cargo': 'Operador Tienda Reponedor para supermercado en Av Bruno Larrain, Salamanca. Turnos Continuos',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operador Tienda Reponedor para supermercado en Av Bruno Larrain, Salamanca. Turnos Continuos',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,7',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d87')},
#  {'Titulo del cargo': 'Operador planta mecanizado /5x2/ Tocopilla',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operador planta mecanizado /5x2/ Tocopilla',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d88')},
#  {'Titulo del cargo': 'Reponedor Nocturno para Supermercado  en Av. Bruno Larrain, Salamanca. Turnos continuos',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Reponedor Nocturno para Supermercado  en Av. Bruno Larrain, Salamanca. Turnos continuos',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,7',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d89')},
#  {'Titulo del cargo': 'Operador Tienda Reponedor para supermercado en Salvador Allende, Illapel. Turnos Continuos',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operador Tienda Reponedor para supermercado en Salvador Allende, Illapel. Turnos Continuos',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,7',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d8a')},
#  {'Titulo del cargo': 'Operario de Terminaciones',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operario de Terminaciones',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Quinta Normal, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d8b')},
#  {'Titulo del cargo': 'Operador de Grúa / Pudahuel Sector Aeropuerto / Turno Rotativos / $705.000',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operador de Grúa / Pudahuel Sector Aeropuerto / Turno Rotativos / $705.000',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d8c')},
#  {'Titulo del cargo': 'Nutricionista Supervisor de Alimentación',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Nutricionista Supervisor de Alimentación',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Nogales, Valparaíso',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d8d')},
#  {'Titulo del cargo': 'Asesor de  Calidad',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Asesor de  Calidad',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Antofagasta, Antofagasta',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d8e')},
#  {'Titulo del cargo': 'Jefe de Bodega / Curanilahue',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Jefe de Bodega / Curanilahue',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Curanilahue, Bíobío',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d8f')},
#  {'Titulo del cargo': 'Auxiliar Dietético / Curanilahue',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar Dietético / Curanilahue',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Curanilahue, Bíobío',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d90')},
#  {'Titulo del cargo': 'Bodeguero / Curanilahue',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Bodeguero / Curanilahue',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Curanilahue, Bíobío',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d91')},
#  {'Titulo del cargo': 'Promotor/a Campaña Cuidado Personal y Perfumería 08 y 09 Mayo/',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Promotor/a Campaña Cuidado Personal y Perfumería 08 y 09 Mayo/',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d92')},
#  {'Titulo del cargo': 'Técnico de Mantenimiento Mecánico de Golosinas. 850.000 liquido. Cerrillos.',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Técnico de Mantenimiento Mecánico de Golosinas. 850.000 liquido. Cerrillos.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d93')},
#  {'Titulo del cargo': 'Práctica profesional Nutricionista',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Práctica profesional Nutricionista',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Vitacura, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d94')},
#  {'Titulo del cargo': 'Práctica profesional Administracion Hotelera',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Práctica profesional Administracion Hotelera',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d95')},
#  {'Titulo del cargo': 'Práctica profesional Prevencion de Riesgos',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Práctica profesional Prevencion de Riesgos',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d96')},
#  {'Titulo del cargo': 'Práctica profesional Marketing',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Práctica profesional Marketing',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Las condes, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d97')},
#  {'Titulo del cargo': 'Vendedores Part Time Lunes a Viernes  La Florida',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vendedores Part Time Lunes a Viernes  La Florida',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Ñuñoa, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d98')},
#  {'Titulo del cargo': 'Vendedores Full Time y Part Time La Serena',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vendedores Full Time y Part Time La Serena',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'La Serena, Coquimbo',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d99')},
#  {'Titulo del cargo': 'Vendedores Multifuncionales',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vendedores Multifuncionales',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'San Bernardo, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d9a')},
#  {'Titulo del cargo': 'auxiliar de aseo',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'auxiliar de aseo',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Rancagua, Libertador B. O Higgins',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d9b')},
#  {'Titulo del cargo': 'Multiétnico',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Multiétnico',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago Centro, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d9c')},
#  {'Titulo del cargo': 'Guardia de seguridad para Renca $557.000 Líquidos mas bono DE 100000 liquido por un mes',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Guardia de seguridad para Renca $557.000 Líquidos mas bono DE 100000 liquido por un mes',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,0',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d9d')},
#  {'Titulo del cargo': 'Aux de aseo industrial turno tarde Quilicura 6x1 $550.000',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Aux de aseo industrial turno tarde Quilicura 6x1 $550.000',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,0',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d9e')},
#  {'Titulo del cargo': 'Técnico Mecánico 4X4',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Técnico Mecánico 4X4',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Maipú, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5d9f')},
#  {'Titulo del cargo': 'Chofer A5',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Chofer A5',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Lampa, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5da0')},
#  {'Titulo del cargo': 'Rutero Promo Vendedores (as) Full Time Zona Oriente',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Rutero Promo Vendedores (as) Full Time Zona Oriente',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Las condes, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5da1')},
#  {'Titulo del cargo': 'Analista Contable decuentas por cobrar con SAP',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Analista Contable decuentas por cobrar con SAP',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Quilicura, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5da2')},
#  {'Titulo del cargo': 'Promo/Vendedor Estación Central',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Promo/Vendedor Estación Central',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Estación Central, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5da3')},
#  {'Titulo del cargo': 'Operario de Caldera',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operario de Caldera',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Quilicura, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5da4')},
#  {'Titulo del cargo': 'Analista de Contabilidad y Finanzas',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Analista de Contabilidad y Finanzas',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Quilicura, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5da5')},
#  {'Titulo del cargo': 'Ejecutivo de Servicio al Cliente',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ejecutivo de Servicio al Cliente',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Providencia, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5da6')},
#  {'Titulo del cargo': 'Consultor de Ventas Automotriz',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Consultor de Ventas Automotriz',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta',
#   '_id': ObjectId('69f0249695aea9e7c6bc5da7')},
#  {'Titulo del cargo': 'Vendedor en Terreno',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vendedor en Terreno',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Concepción, Bíobío',
#   '_id': ObjectId('69f0249695aea9e7c6bc5da8')},
#  {'Titulo del cargo': 'Ingeniero en Prevención de Riesgos Sernageomin',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ingeniero en Prevención de Riesgos Sernageomin',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Copiapó, Atacama',
#   '_id': ObjectId('69f0249695aea9e7c6bc5da9')},
#  {'Titulo del cargo': 'Ingeniero en Prevención de Riesgos',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ingeniero en Prevención de Riesgos',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Copiapó, Atacama',
#   '_id': ObjectId('69f0249695aea9e7c6bc5daa')},
#  {'Titulo del cargo': 'Operario/a de Bodega Full Time Salida directa',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operario/a de Bodega Full Time Salida directa',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'San Bernardo, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dab')},
#  {'Titulo del cargo': 'Electromecánico Sec',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Electromecánico Sec',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Copiapó, Atacama',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dac')},
#  {'Titulo del cargo': 'Ingeniero/a de Confiabilidad y Mantención Mecánica',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ingeniero/a de Confiabilidad y Mantención Mecánica',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'La Unión, Los Ríos',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dad')},
#  {'Titulo del cargo': 'Promotor(a) de Perfumes y Skincare / $30.000 líquidos /Campaña del día de la madre / Santiago Centro',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Promotor(a) de Perfumes y Skincare / $30.000 líquidos /Campaña del día de la madre / Santiago Centro',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dae')},
#  {'Titulo del cargo': 'Analista Químico desarrollo e investigación / Zona sur',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Analista Químico desarrollo e investigación / Zona sur',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Providencia, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5daf')},
#  {'Titulo del cargo': 'Transportador Clinico (Camillero) para Clínico Ubicada en Vitacura',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Transportador Clinico (Camillero) para Clínico Ubicada en Vitacura',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,3',
#   '_id': ObjectId('69f0249695aea9e7c6bc5db0')},
#  {'Titulo del cargo': 'Jefe de Terreno',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Jefe de Terreno',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Calama, Antofagasta',
#   '_id': ObjectId('69f0249695aea9e7c6bc5db1')},
#  {'Titulo del cargo': 'Vendedor/a en Terreno Santiago.',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vendedor/a en Terreno Santiago.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,1',
#   '_id': ObjectId('69f0249695aea9e7c6bc5db2')},
#  {'Titulo del cargo': 'Operarios Sorter para Pudahuel $700.000 Lunes a sábado Turno Rotativo',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operarios Sorter para Pudahuel $700.000 Lunes a sábado Turno Rotativo',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,0',
#   '_id': ObjectId('69f0249695aea9e7c6bc5db3')},
#  {'Titulo del cargo': 'Vendedor/a en terreno para el Antofagasta¡Sin experiencia + Altas Comisiones!',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vendedor/a en terreno para el Antofagasta¡Sin experiencia + Altas Comisiones!',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,1',
#   '_id': ObjectId('69f0249695aea9e7c6bc5db4')},
#  {'Titulo del cargo': 'Administrador de Contrato Servicio Aseo y Facility Hospitalario La Serena Turno 5x2',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Administrador de Contrato Servicio Aseo y Facility Hospitalario La Serena Turno 5x2',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'La Serena, Coquimbo',
#   '_id': ObjectId('69f0249695aea9e7c6bc5db5')},
#  {'Titulo del cargo': 'Ejecutiva de cuentas /Renca/ $640.000 + Colación / Lunes a viernes',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ejecutiva de cuentas /Renca/ $640.000 + Colación / Lunes a viernes',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5db6')},
#  {'Titulo del cargo': 'Ayudante de Cocina Las Condes / Solo Domingos de 09.00 a 17.00 horas',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ayudante de Cocina Las Condes / Solo Domingos de 09.00 a 17.00 horas',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Las condes, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5db7')},
#  {'Titulo del cargo': 'Operario/a de planta (Lavanderia)/Sábados/ San Francisco de Mostazal/ $27.000 diarios',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operario/a de planta (Lavanderia)/Sábados/ San Francisco de Mostazal/ $27.000 diarios',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,0',
#   '_id': ObjectId('69f0249695aea9e7c6bc5db8')},
#  {'Titulo del cargo': 'Operario de ropería en ruta/ Santiago/$599.000 liquidos',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operario de ropería en ruta/ Santiago/$599.000 liquidos',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,0',
#   '_id': ObjectId('69f0249695aea9e7c6bc5db9')},
#  {'Titulo del cargo': 'Promotor/a Part Time Maipú',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Promotor/a Part Time Maipú',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,9',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dba')},
#  {'Titulo del cargo': 'Jardinero  $42.500 Líquido por día trabajado / Los Angeles.',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Jardinero  $42.500 Líquido por día trabajado / Los Angeles.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dbb')},
#  {'Titulo del cargo': 'Técnico Automotriz La Florida',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Técnico Automotriz La Florida',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,9',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dbc')},
#  {'Titulo del cargo': 'Auxiliar Dietética 2x2 día',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar Dietética 2x2 día',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - La Florida, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dbd')},
#  {'Titulo del cargo': 'Auxiliar de Higiene / Limpieza Turno Tarde 14:00hrs a 22:00hrs en Estación Central',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar de Higiene / Limpieza Turno Tarde 14:00hrs a 22:00hrs en Estación Central',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,3',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dbe')},
#  {'Titulo del cargo': 'Vidriero interior 6x1 08:00 a 16:00 hrs Comuna Recoleta',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vidriero interior 6x1 08:00 a 16:00 hrs Comuna Recoleta',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,3',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dbf')},
#  {'Titulo del cargo': 'Ayudante de Bodega Quilicura',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ayudante de Bodega Quilicura',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,1',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dc0')},
#  {'Titulo del cargo': 'Auxiliar de Limpieza Renca Lo Boza turno AM',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar de Limpieza Renca Lo Boza turno AM',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,3',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dc1')},
#  {'Titulo del cargo': 'Auxiliar de Cocina para Pudahuel (Reemplazo Vacaciones)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar de Cocina para Pudahuel (Reemplazo Vacaciones)',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,4',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dc2')},
#  {'Titulo del cargo': 'Encargado(a) de bodega (Inventario) con licencia D/ Renca / Lunes a viernes/690.000',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Encargado(a) de bodega (Inventario) con licencia D/ Renca / Lunes a viernes/690.000',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dc3')},
#  {'Titulo del cargo': 'Contador auditor',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Contador auditor',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Huechuraba, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dc4')},
#  {'Titulo del cargo': 'Especialista en Ventas y Asesoría de Belleza /Huechuraba',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Especialista en Ventas y Asesoría de Belleza /Huechuraba',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dc5')},
#  {'Titulo del cargo': 'Auxiliar de Aseo + Bus de Acercamiento + Colación',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar de Aseo + Bus de Acercamiento + Colación',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,0',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dc6')},
#  {'Titulo del cargo': 'Picker o Armador de Pedidos para Supermercado en Renca, RM.',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Picker o Armador de Pedidos para Supermercado en Renca, RM.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,7',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dc7')},
#  {'Titulo del cargo': 'Operador Tienda Cajero/a de Supermercado en Conchalí, RM.',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operador Tienda Cajero/a de Supermercado en Conchalí, RM.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,7',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dc8')},
#  {'Titulo del cargo': 'Especialista en Ventas y Asesoría de Belleza /Limache',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Especialista en Ventas y Asesoría de Belleza /Limache',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dc9')},
#  {'Titulo del cargo': 'Carga y Descarga de Camiones / Ingreso Inmediato / $25.000 lqd diarios/ Melipilla',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Carga y Descarga de Camiones / Ingreso Inmediato / $25.000 lqd diarios/ Melipilla',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dca')},
#  {'Titulo del cargo': 'Asistente de Operaciones/$650.000 líquidos / Ingreso hoy 08 hasta el dia 17 de abril / Copiapó',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Asistente de Operaciones/$650.000 líquidos / Ingreso hoy 08 hasta el dia 17 de abril / Copiapó',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dcb')},
#  {'Titulo del cargo': 'Alumno en practica distintas áreas',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Alumno en practica distintas áreas',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,9',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dcc')},
#  {'Titulo del cargo': 'Grueroy apilador eléctrico 730',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Grueroy apilador eléctrico 730',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,0',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dcd')},
#  {'Titulo del cargo': 'Operador de Sistemas de Aguas Servidas / Rancagua',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operador de Sistemas de Aguas Servidas / Rancagua',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dce')},
#  {'Titulo del cargo': 'Supervisor de Ventas en Terreno  – Venta Maquinas POS Viña',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Supervisor de Ventas en Terreno  – Venta Maquinas POS Viña',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Viña del Mar, Valparaíso',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dcf')},
#  {'Titulo del cargo': 'Especialista SAP Supply Chain, Huechuraba',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Especialista SAP Supply Chain, Huechuraba',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Providencia, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dd0')},
#  {'Titulo del cargo': 'Cajera con Experiencia en Fonasa',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cajera con Experiencia en Fonasa',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Talcahuano, Bíobío',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dd1')},
#  {'Titulo del cargo': 'Consultor/a de belleza de lujo Full time',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Consultor/a de belleza de lujo Full time',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,1',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dd2')},
#  {'Titulo del cargo': 'Supervisor de Aseo / Industrial',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Supervisor de Aseo / Industrial',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Pudahuel, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dd3')},
#  {'Titulo del cargo': 'Especialista en Ventas y Asesoría de Belleza / Peñalolen',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Especialista en Ventas y Asesoría de Belleza / Peñalolen',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dd4')},
#  {'Titulo del cargo': 'Supervisor/a de aseo',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Supervisor/a de aseo',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Independencia, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dd5')},
#  {'Titulo del cargo': 'Picker o Armador de pedidos de Supermercado en Santiago Centro',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Picker o Armador de pedidos de Supermercado en Santiago Centro',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,7',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dd6')},
#  {'Titulo del cargo': 'Asesor al Cliente PRO Quilicura',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Asesor al Cliente PRO Quilicura',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,7',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dd7')},
#  {'Titulo del cargo': 'Asesor al Cliente PRO Cerrillos',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Asesor al Cliente PRO Cerrillos',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,7',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dd8')},
#  {'Titulo del cargo': 'Vendedor/a testeador/a para el mes de mayo',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vendedor/a testeador/a para el mes de mayo',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dd9')},
#  {'Titulo del cargo': 'Gestor Merchandising en Ruta/ Chillán',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Gestor Merchandising en Ruta/ Chillán',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,3',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dda')},
#  {'Titulo del cargo': 'Gestor Merchandising en Ruta/ San Fernando',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Gestor Merchandising en Ruta/ San Fernando',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,3',
#   '_id': ObjectId('69f0249695aea9e7c6bc5ddb')},
#  {'Titulo del cargo': 'Gestor Merchandising en Ruta/ Litoral central',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Gestor Merchandising en Ruta/ Litoral central',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,3',
#   '_id': ObjectId('69f0249695aea9e7c6bc5ddc')},
#  {'Titulo del cargo': 'Operarios(as) de Bodega PT Tarde 12:00 a 18:00 Pudahuel Puerto Madero $410000',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operarios(as) de Bodega PT Tarde 12:00 a 18:00 Pudahuel Puerto Madero $410000',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Pudahuel, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5ddd')},
#  {'Titulo del cargo': 'Auxiliar de Aseo Casino / 6x1 / turno rotativos',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar de Aseo Casino / 6x1 / turno rotativos',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Providencia, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5dde')},
#  {'Titulo del cargo': 'Asesor de ventas/ Productos de calefacción Campaña Invierno 2026',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Asesor de ventas/ Productos de calefacción Campaña Invierno 2026',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,1',
#   '_id': ObjectId('69f0249695aea9e7c6bc5ddf')},
#  {'Titulo del cargo': 'Auxiliar de Farmacia Part Time',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar de Farmacia Part Time',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Puerto Montt, Los Lagos',
#   '_id': ObjectId('69f0249695aea9e7c6bc5de0')},
#  {'Titulo del cargo': 'Medico Cirujano Viña del Mar',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Medico Cirujano Viña del Mar',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,9',
#   '_id': ObjectId('69f0249695aea9e7c6bc5de1')},
#  {'Titulo del cargo': 'Operador de Tienda / Cajero para Supermercado en Conchali',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operador de Tienda / Cajero para Supermercado en Conchali',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,7',
#   '_id': ObjectId('69f0249695aea9e7c6bc5de2')},
#  {'Titulo del cargo': 'Operarios de elaboracion de medicamentos',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operarios de elaboracion de medicamentos',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5de3')},
#  {'Titulo del cargo': 'Auxiliar de aseo Full Time 630000 liquidos',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar de aseo Full Time 630000 liquidos',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Las condes, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5de4')},
#  {'Titulo del cargo': 'Vendedor/a testeador/a part time mes de mayo',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vendedor/a testeador/a part time mes de mayo',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5de5')},
#  {'Titulo del cargo': 'Bodeguero Rubro Automotriz',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Bodeguero Rubro Automotriz',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Las condes, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5de6')},
#  {'Titulo del cargo': 'Vendedora captadora AM 30hrs de lunes a viernes',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
# ...
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Operarios/as de Bodega 630.000 liquidos',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,9',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f4c')},
#  {'Titulo del cargo': 'Vendedor/a en Terreno V Region (Comisiones SIN Tope)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vendedor/a en Terreno V Region (Comisiones SIN Tope)',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,1',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f4d')},
#  {'Titulo del cargo': 'Ordenadores de Carros  de supermercado en Huechuraba/ fin de semana.',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ordenadores de Carros  de supermercado en Huechuraba/ fin de semana.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,7',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f4e')},
#  {'Titulo del cargo': 'Ordenadores de Carros  de supermercado en Lampa / larapinta/ fin de semana.',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ordenadores de Carros  de supermercado en Lampa / larapinta/ fin de semana.',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '3,7',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f4f')},
#  {'Titulo del cargo': 'Guardia de Seguridad en La Union',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Guardia de Seguridad en La Union',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'La Unión, Los Ríos',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f50')},
#  {'Titulo del cargo': 'Auxiliar de aseo para Colegio en Vitacura, Mañana y Tarde',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar de aseo para Colegio en Vitacura, Mañana y Tarde',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Vitacura, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f51')},
#  {'Titulo del cargo': 'Auxiliar de aseo centro educacional, Tarde, Chicureo',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar de aseo centro educacional, Tarde, Chicureo',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Colina, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f52')},
#  {'Titulo del cargo': 'Consultor/a de Belleza (Campaña día de la Madre )',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Consultor/a de Belleza (Campaña día de la Madre )',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f53')},
#  {'Titulo del cargo': 'Grua Horquilla La Serena/ $720.000',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Grua Horquilla La Serena/ $720.000',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f54')},
#  {'Titulo del cargo': 'Cajero Bancario Ancud',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Cajero Bancario Ancud',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f55')},
#  {'Titulo del cargo': 'Analista de Marketing',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Analista de Marketing',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f56')},
#  {'Titulo del cargo': 'Vidriero base y altura',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vidriero base y altura',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,0',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f57')},
#  {'Titulo del cargo': 'Reponedor supermercado/ La Reina',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Reponedor supermercado/ La Reina',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f58')},
#  {'Titulo del cargo': 'Auxiliar de casino apoyo',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar de casino apoyo',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Providencia, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f59')},
#  {'Titulo del cargo': 'Vendedor de Telefonía Full Time para Villarrica',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vendedor de Telefonía Full Time para Villarrica',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Villarrica, Araucanía',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f5a')},
#  {'Titulo del cargo': 'Vendedor de Telefonía Full Time para Osorno',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vendedor de Telefonía Full Time para Osorno',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Osorno, Los Lagos',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f5b')},
#  {'Titulo del cargo': 'Vendedor de Telefonía Full Time para Puerto Montt',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Vendedor de Telefonía Full Time para Puerto Montt',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Puerto Montt, Los Lagos',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f5c')},
#  {'Titulo del cargo': 'Diseñador Grafico, Empresa Retail, Cerrillos',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Diseñador Grafico, Empresa Retail, Cerrillos',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Providencia, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f5d')},
#  {'Titulo del cargo': 'Ejecutivo/a Banca Personas, Talca (Plazo Fijo)',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Ejecutivo/a Banca Personas, Talca (Plazo Fijo)',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,6',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f5e')},
#  {'Titulo del cargo': 'Controlador Central Full Time Clínica Bupa',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Controlador Central Full Time Clínica Bupa',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - La Florida, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f5f')},
#  {'Titulo del cargo': 'Electromecánico / Eléctrico / La Negra, Antofagasta',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Electromecánico / Eléctrico / La Negra, Antofagasta',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f60')},
#  {'Titulo del cargo': 'Auxiliar de Aseo / Talagante',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar de Aseo / Talagante',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f61')},
#  {'Titulo del cargo': 'Soldador Mantenedor Calificado',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Soldador Mantenedor Calificado',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Iquique, Tarapacá',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f62')},
#  {'Titulo del cargo': 'Supervisor/a de Sondaje',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Supervisor/a de Sondaje',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Pozo Almonte, Tarapacá',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f63')},
#  {'Titulo del cargo': 'Administrativo Servicio al cliente bilingüe',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Administrativo Servicio al cliente bilingüe',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,2',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f64')},
#  {'Titulo del cargo': 'Supervisor Operación en Vivero/  Minera los pelambres EP036/26',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Supervisor Operación en Vivero/  Minera los pelambres EP036/26',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Salamanca, Coquimbo',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f65')},
#  {'Titulo del cargo': 'Instalador Sanitario',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Instalador Sanitario',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Río Bueno, Los Ríos',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f66')},
#  {'Titulo del cargo': 'Gasfíter SEC',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Gasfíter SEC',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Lampa, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f67')},
#  {'Titulo del cargo': 'Guardia de seguridad/7x7 rotativo/ 750000/ Minería',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Guardia de seguridad/7x7 rotativo/ 750000/ Minería',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,0',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f68')},
#  {'Titulo del cargo': 'Auxiliar Dietética Turno Noche',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Auxiliar Dietética Turno Noche',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Maipú, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f69')},
#  {'Titulo del cargo': 'Asistente de Bodega',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Asistente de Bodega',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Pudahuel, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f6a')},
#  {'Titulo del cargo': 'Supervisor de seguridad/ Calama',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Supervisor de seguridad/ Calama',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': '4,0',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f6b')},
#  {'Titulo del cargo': 'Consultor de Reclutamiento y Selección',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Consultor de Reclutamiento y Selección',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Providencia, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f6c')},
#  {'Titulo del cargo': 'Urgente!! Conductor de Taxibus (33 Pasajeros) / 6x1',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Urgente!! Conductor de Taxibus (33 Pasajeros) / 6x1',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Quilicura, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f6d')},
#  {'Titulo del cargo': 'supervisor operaciones',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'supervisor operaciones',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Providencia, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f6e')},
#  {'Titulo del cargo': 'Urgente!! Conductor de Bus (44  Pasajeros) / 6x1',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Urgente!! Conductor de Bus (44  Pasajeros) / 6x1',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Macul, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f6f')},
#  {'Titulo del cargo': 'Coordinador de Selección',
#   'País': 'Chile',
#   'Modalidad de trabajo': 'Presencial',
#   'Fecha': '28/04/2026',
#   'Tipo de moneda': 'CLP',
#   'Categoría de empleo': 'Varios',
#   'Tipo de horario (Extra)': 'Jornada Completa',
#   'Empresa': 'Coordinador de Selección',
#   'Integrante': 'Lizette-Sanmartin',
#   'Ciudad': 'Santiago - Providencia, R.Metropolitana',
#   '_id': ObjectId('69f0249695aea9e7c6bc5f70')}]

# %%
# !pip install --upgrade webdriver-manager selenium
# Out:
# Requirement already satisfied: webdriver-manager in /opt/conda/lib/python3.11/site-packages (4.0.2)
# Requirement already satisfied: selenium in /opt/conda/lib/python3.11/site-packages (4.43.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from webdriver-manager) (2.31.0)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.11/site-packages (from webdriver-manager) (1.2.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from webdriver-manager) (23.2)
# Requirement already satisfied: certifi>=2026.1.4 in /opt/conda/lib/python3.11/site-packages (from selenium) (2026.4.22)
# Requirement already satisfied: trio<1.0,>=0.31.0 in /opt/conda/lib/python3.11/site-packages (from selenium) (0.33.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in /opt/conda/lib/python3.11/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in /opt/conda/lib/python3.11/site-packages (from selenium) (4.15.0)
# Requirement already satisfied: urllib3<3.0,>=2.6.3 in /opt/conda/lib/python3.11/site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (2.6.3)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /opt/conda/lib/python3.11/site-packages (from selenium) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in /opt/conda/lib/python3.11/site-packages (from trio<1.0,>=0.31.0->selenium) (26.1.0)
# Requirement already satisfied: sortedcontainers in /opt/conda/lib/python3.11/site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from trio<1.0,>=0.31.0->selenium) (3.4)
# Requirement already satisfied: outcome in /opt/conda/lib/python3.11/site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/conda/lib/python3.11/site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /opt/conda/lib/python3.11/site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.2)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /opt/conda/lib/python3.11/site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.16.0 in /opt/conda/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->webdriver-manager) (3.3.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip
