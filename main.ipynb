# %% [markdown]
# # Proyecto Big Data 2026 — Equipo Mercado Laboral
# **Instrucciones:** Ejecuta primero la celda de inicialización, luego cada scraper por separado. Al terminar todos, ejecuta la celda de carga a MongoDB.

# %%
# ─────────────────────────────────────────
# INICIALIZACIÓN — Ejecutar SIEMPRE primero
# ─────────────────────────────────────────
datos_diego      = []
datos_sofia      = []
datos_benja      = []
datos_giannella  = []
datos_denis      = []
datos_nicolas    = []
datos_lizette    = []
print('Variables inicializadas. Puedes correr los scrapers en cualquier orden.')
# Out:
# Variables inicializadas. Puedes correr los scrapers en cualquier orden.

# %%
# ─────────────────────────────────────────
# Diego Castillo — getonbrd.com
# ─────────────────────────────────────────
import pandas as pd
from Scrapers.Scraper_Diego import ejecutar_extraccionD

print('Iniciando extracción: Diego Castillo...')
datos_diego = ejecutar_extraccionD()

if datos_diego:
    df_diego = pd.DataFrame(datos_diego)
    print(f'\nTotal capturado: {len(df_diego)} registros')
    display(df_diego)
else:
    print('No se capturaron datos.')
# Out:
# Iniciando extracción: Diego Castillo...
#
# ========== Categoría: Programación ==========
#   --- Página 1 ---
#   Ofertas encontradas: 70
#   No hay más páginas en esta categoría.
#
# ========== Categoría: Diseño ==========
#   --- Página 1 ---
#   Ofertas encontradas: 29
#   No hay más páginas en esta categoría.
#
# ========== Categoría: Marketing ==========
#   --- Página 1 ---
#   Ofertas encontradas: 14
#   No hay más páginas en esta categoría.
#
# ========== Categoría: Data ==========
#   --- Página 1 ---
#   Ofertas encontradas: 37
#   No hay más páginas en esta categoría.
#
# ========== Categoría: Soporte y QA ==========
#   --- Página 1 ---
#   Ofertas encontradas: 100
#   No hay más páginas en esta categoría.
#
# ========== Categoría: Ventas ==========
#   --- Página 1 ---
#   Ofertas encontradas: 15
#   No hay más páginas en esta categoría.
#
# ========== Categoría: Gestión y Negocios ==========
#   --- Página 1 ---
#   Ofertas encontradas: 100
# ...

# %%
# ─────────────────────────────────────────
# Sofia Urquieta — firstjob.me
# ─────────────────────────────────────────
import pandas as pd
from Scrapers.Scraper_SofiaUrquieta import ejecutar_scraping_firstjob

print('Iniciando extracción: Sofia Urquieta...')
datos_sofia = ejecutar_scraping_firstjob()

if datos_sofia:
    df_sofia = pd.DataFrame(datos_sofia)
    print(f'\nTotal capturado: {len(df_sofia)} registros')
    display(df_sofia)
else:
    print('No se capturaron datos.')
# Out:
# Iniciando extracción: Sofia Urquieta...
# Iniciando recoleccion para Sofia-Urquieta...
#
# ========== Pagina 1 ==========
#   Ofertas encontradas: 19
# Progreso: 19 registros capturados.
#
# ========== Pagina 2 ==========
#   Ofertas encontradas: 20
# Progreso: 39 registros capturados.
#
# ========== Pagina 3 ==========
#   Ofertas encontradas: 20
# Progreso: 59 registros capturados.
#
# ========== Pagina 4 ==========
#   Ofertas encontradas: 20
# Progreso: 79 registros capturados.
#
# ========== Pagina 5 ==========
#   Ofertas encontradas: 20
# Progreso: 99 registros capturados.
#
# ========== Pagina 6 ==========
#   Ofertas encontradas: 20
# Progreso: 119 registros capturados.
#
# ========== Pagina 7 ==========
#   Ofertas encontradas: 20
# Progreso: 139 registros capturados.
#
# ========== Pagina 8 ==========
#   Ofertas encontradas: 20
# Progreso: 159 registros capturados.
#
# ========== Pagina 9 ==========
#   Ofertas encontradas: 20
# Progreso: 179 registros capturados.
#
# ...

# %%
# ─────────────────────────────────────────
# Benjamin Ramirez
# ─────────────────────────────────────────
import pandas as pd
from Scrapers.scraper_benja import ejecutar_extraccion

print('Iniciando extracción: Benjamin Ramirez...')
datos_benja = ejecutar_extraccion()

if datos_benja:
    df_benja = pd.DataFrame(datos_benja)
    print(f'\nTotal capturado: {len(df_benja)} registros')
    display(df_benja)
else:
    print('No se capturaron datos.')

# %%
# ─────────────────────────────────────────
# Giannella Rieu
# ─────────────────────────────────────────
import pandas as pd
from Scrapers.scraper_giannella import extraer_empleos

print('Iniciando extracción: Giannella Rieu...')
datos_giannella = extraer_empleos(
    nombre_grupo="Giannella-Rieu",
    meta_registros=1000,
    limite_paginas=25
)

if datos_giannella:
    df_giannella = pd.DataFrame(datos_giannella)
    print(f'\nTotal capturado: {len(df_giannella)} registros')
    display(df_giannella)
else:
    print('No se capturaron datos.')
# Out:
# Iniciando extracción: Giannella Rieu...
# Iniciando extracción — Grupo: Giannella Rieu | Meta: 1000 registros
#
# Descargando chromedriver 148.0.7778.178 desde storage.googleapis.com...
# chromedriver listo: /home/jovyan/.chromedriver/148.0.7778.178/chromedriver
# ========== Categoría: Informatica ==========
#   Página 1: 16 nuevos | Total: 16
#   Página 2: 14 nuevos | Total: 30
#   Página 3: 10 nuevos | Total: 40
#   Página 4: 16 nuevos | Total: 56
#   Página 5: 16 nuevos | Total: 72
#   Página 6: 15 nuevos | Total: 87
#   Página 7: 16 nuevos | Total: 103
#   Página 8: 13 nuevos | Total: 116
#   Página 9: 16 nuevos | Total: 132
#   Página 10: 15 nuevos | Total: 147
#   Página 11: 16 nuevos | Total: 163
#   Página 12: 16 nuevos | Total: 179
#   Página 13: 14 nuevos | Total: 193
#   Página 14: 15 nuevos | Total: 208
#   Página 15: 15 nuevos | Total: 223
#   Página 16: 16 nuevos | Total: 239
#   Página 17: 15 nuevos | Total: 254
#   Página 18: 16 nuevos | Total: 270
# ...

# %%
# ─────────────────────────────────────────
# Denis Baez
# ─────────────────────────────────────────
import pandas as pd
from Scrapers.scraper_denis_baez import ejecutar_extraccion

print('Iniciando extracción: Denis Baez...')
datos_denis = ejecutar_extraccion()

if datos_denis:
    df_denis = pd.DataFrame(datos_denis)
    print(f'\nTotal capturado: {len(df_denis)} registros')
    display(df_denis)
else:
    print('No se capturaron datos.')

# %%
# ─────────────────────────────────────────
# Nicolas Jorgensen
# ─────────────────────────────────────────
import pandas as pd
from Scrapers.scraper_nicolas import ejecutar_extraccion_nicolas

print('Iniciando extracción: Nicolas Jorgensen...')
datos_nicolas = ejecutar_extraccion_nicolas()

if datos_nicolas:
    df_nicolas = pd.DataFrame(datos_nicolas)
    print(f'\nTotal capturado: {len(df_nicolas)} registros')
    display(df_nicolas)
else:
    print('No se capturaron datos.')

# %%
# ─────────────────────────────────────────
# Lizette San Martin
# ─────────────────────────────────────────
import pandas as pd
from Scrapers.scraper_lizette import ejecutar_extraccion_lizette

print('Iniciando extracción: Lizette San Martin...')
datos_lizette = ejecutar_extraccion_lizette()

if datos_lizette:
    df_lizette = pd.DataFrame(datos_lizette)
    print(f'\nTotal capturado: {len(df_lizette)} registros')
    display(df_lizette)
else:
    print('No se capturaron datos.')

# %%
# ═══════════════════════════════════════════════════════════
# CARGA UNIFICADA A MONGODB ATLAS
# Ejecutar esta celda DESPUÉS de que todos los scrapers terminen
# ═══════════════════════════════════════════════════════════
import certifi
from pymongo import MongoClient

MONGO_URI = 'mongodb+srv://BenjaminRamirez:fim5S0MTo17YVRw0@cluster0.kek1o3u.mongodb.net/?retryWrites=true&w=majority'

todos_los_datos = [
    ('Diego Castillo',    datos_diego),
    ('Sofia Urquieta',    datos_sofia),
    ('Benjamin Ramirez',  datos_benja),
    ('Giannella Rieu',    datos_giannella),
    ('Denis Baez',        datos_denis),
    ('Nicolas Jorgensen', datos_nicolas),
    ('Lizette San Martin',datos_lizette),
]

try:
    client    = MongoClient(MONGO_URI, tlsCAFile=certifi.where())
    db        = client['Proyecto_Bigdata']
    coleccion = db['Registros_Scraping']
    print('Conexion establecida con MongoDB Atlas.')
except Exception as e:
    print(f'ERROR de conexion: {e}')
    raise

total_exitosos = 0
total_fallidos = 0

for integrante, datos in todos_los_datos:
    if not datos:
        print(f'  [{integrante}] Sin datos, se omite.')
        continue

    exitosos = 0
    fallidos = 0

    for dato in datos:
        try:
            url_key = dato.get('URL_Oferta') or dato.get('url_oferta') or dato.get('url')
            if url_key:
                coleccion.update_one({'URL_Oferta': url_key}, {'$set': dato}, upsert=True)
            else:
                coleccion.insert_one(dato)
            exitosos += 1
        except Exception as e:
            fallidos += 1

    print(f'  [{integrante}] Exitosos: {exitosos} | Fallidos: {fallidos}')
    total_exitosos += exitosos
    total_fallidos += fallidos

print(f'\n══ RESUMEN FINAL ══')
print(f'  Total subidos     : {total_exitosos}')
print(f'  Total fallidos    : {total_fallidos}')
print(f'  Total en coleccion: {coleccion.count_documents({})}')

client.close()
# Out:
# Conexion establecida con MongoDB Atlas.
#   [Diego Castillo] Sin datos, se omite.
#   [Sofia Urquieta] Exitosos: 500 | Fallidos: 0
#   [Benjamin Ramirez] Sin datos, se omite.
#   [Giannella Rieu] Sin datos, se omite.
#   [Denis Baez] Sin datos, se omite.
#   [Nicolas Jorgensen] Sin datos, se omite.
#   [Lizette San Martin] Sin datos, se omite.
#
# ══ RESUMEN FINAL ══
#   Total subidos     : 500
#   Total fallidos    : 0
#   Total en coleccion: 6098
