# %%
# Resumen de variables del mercado laboral
df_clean.select("Título de cargo", "Empresa", "País", "Modalidad", "Tipo de horario").describe().show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Resumen de variables del mercado laboral
# ----> 2 df_clean.select("Título de cargo", "Empresa", "País", "Modalidad", "Tipo de horario").describe().show()
#
# NameError: name 'df_clean' is not defined
