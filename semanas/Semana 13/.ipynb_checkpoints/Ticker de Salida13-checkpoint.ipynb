# %%
### Pregunta 1: ¿Cómo se solucionaría en el mundo real? ¿Qué datos faltan?


R: El problema son los datos, no el algoritmo. La Regresión Lineal funciona correctamente 
como herramienta matemática, pero los datos disponibles en el dataset de JobRapido no contienen ninguna 
variable que tenga una relación causal real con las features utilizadas.

En este caso se usó el largo de la descripción (`desc_len`) como variable objetivo,
un dato que sí existe, pero que no depende de forma lineal de la modalidad,
el tipo de horario ni la categoría del empleo. Una oferta de trabajo presencial puede tener una descripción 
corta o larga independientemente de su sector
.Por eso el modelo obtiene un R² muy bajo (cercano a 0%): las variables predictoras dadas simplemente 
no explican la variable objetivo.

El algoritmo no puede aprender lo que los datos no contienen.

# %%
### Pregunta 2: ¿Cómo se solucionaría en el mundo real? ¿Qué datos faltan?

R En el mundo real, la variable que realmente tiene valor de negocio para predecir en un dataset 
de ofertas laborales es el salario o rango salarial.
Con esa columna, la Regresión Lineal cobraría todo su sentido: predecir cuánto paga una oferta 
en función de sus características.

Los datos que faltan en el dataset original de JobRapido para que la regresión sea útil son:

- Sueldo / rango salarial ← la variable objetivo más obvia y valiosa
- Años de experiencia requeridos (ej: 0-1 años, 2-5 años, +5 años)
- Nivel educacional exigido (técnico, universitario, postgrado)
- Región / ciudad dentro de Chile (el mercado de Santiago vs regiones difiere en sueldos)
- Tamaño de la empresa (startup, pyme, multinacional)
- Tipo de contrato (indefinido, plazo fijo, por obra, honorarios)
- Habilidades específicas requeridas (ej: Python, Excel, maquinaria, idiomas)

Con esos datos, el modelo podría responder preguntas de alto valor real como:  
¿Cuánto más gana alguien en modalidad remota vs presencial en el sector de Informática?
¿Qué variables determinan más el sueldo en el mercado laboral chileno?

Sin la variable objetivo correcta (salario), cualquier modelo de regresión sobre este 
dataset estará limitado por los datos, no por el algoritmo.
