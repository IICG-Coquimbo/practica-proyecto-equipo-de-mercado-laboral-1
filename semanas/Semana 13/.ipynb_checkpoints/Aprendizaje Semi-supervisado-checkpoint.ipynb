# %% [raw]
# Aprendizaje Semi-supervisado (Ticket de salida semana 13)

# %% [markdown]
# ¿El problema es el algoritmo o los datos?

# %%
El problema radica absolutamente en los datos, no en el algoritmo. La Regresión Lineal matemática funciona de manera correcta,
pero existe una ausencia total de correlación real entre las variables predictoras seleccionadas (rating y opiniones) y la variable objetivo (precio_kg)

# %% [markdown]
# ¿Cómo lo solucionarían en el mundo real sin hacer trampa? qué datos faltan en el dataset original que sí determinen el precio de un producto veterinario
# (por ejemplo: costo de la materia prima, margen de ganancia de la tienda, si es importado o nacional, peso neto del empaque, etc.). O en sus datos,
# como fué el algoritmo?

# %%
Se debe solucionar mediante la incorporación de variables de negocio reales que sí determinen el precio de un producto veterinario, tales como: 
el costo de las materias primas, El tamaño y peso neto del empaque o el margen de ganancia de la tienda o canal de distribución.
