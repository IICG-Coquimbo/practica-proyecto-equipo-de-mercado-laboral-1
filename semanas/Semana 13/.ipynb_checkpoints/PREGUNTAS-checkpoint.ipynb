# %%
1. ¿El problema es el algoritmo o los datos?

# %%
El principal problema son los datos. El algoritmo de Regresión Lineal funciona correctamente, pero las variables utilizadas 
(rating y opiniones) no son suficientes para explicar el precio real de un producto veterinario. Estas variables tienen una 
relación débil con el costo comercial del producto, por lo que el modelo no puede hacer predicciones muy precisas.
También influye que la Regresión Lineal es un modelo simple y puede no capturar relaciones más complejas entre las variables.

# %%
2. ¿Cómo lo solucionarían en el mundo real sin hacer trampa? ¿Qué datos faltan en el dataset original?

# %%
En el mundo real se solucionaría recolectando más información relevante sobre los productos. Algunos datos importantes que faltan son:

costo de producción,
peso neto del empaque,
si el producto es importado o nacional,
calidad de ingredientes,
tipo de alimento,
margen de ganancia de la tienda,
costos de transporte,
impuestos,
categoría premium o económica,
tamaño del empaque,
promociones o descuentos.

Con estas variables el modelo tendría información mucho más útil para entender qué factores determinan el precio real de los productos veterinarios y 
las predicciones serían más precisas.
