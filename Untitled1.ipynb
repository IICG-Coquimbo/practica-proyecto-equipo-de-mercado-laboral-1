# %%
# %load_ext autoreload
# %autoreload 2
from scraper.scraper_benjamin import ejecutar_extraccion
ejecutar_extraccion()
# Out:
# Iniciando extracción multi-categoría para Benjamin-Ramirez...
# Explorando categoría: informatica...
# Acumulados: 30/500
# Explorando categoría: administracion...
# Acumulados: 59/500
# Explorando categoría: ventas...
# Acumulados: 82/500
# Explorando categoría: comercial...
# Acumulados: 90/500
# Explorando categoría: bodega...
# Acumulados: 116/500
# Explorando categoría: logistica...
# Acumulados: 134/500
# Explorando categoría: secretaria...
# Acumulados: 163/500
# Explorando categoría: recepcion...
# Acumulados: 173/500
# Explorando categoría: contabilidad...
# Acumulados: 192/500
# Explorando categoría: finanzas...
# Acumulados: 203/500
# Explorando categoría: recursos-humanos...
# Acumulados: 225/500
# Explorando categoría: marketing...
# Acumulados: 246/500
# Explorando categoría: salud...
# Acumulados: 264/500
# Explorando categoría: educacion...
# Acumulados: 287/500
# Explorando categoría: ingenieria...
# Acumulados: 296/500
# Explorando categoría: construccion...
# ...
